# %% [markdown]
# # U-Net: Convolutional Networks for Biomedical Image Segmentation
#
# ![Screenshot%202022-12-08%20at%2011.27.36%20PM.png](attachment:Screenshot%202022-12-08%20at%2011.27.36%20PM.png)
#
# ## Convolution Output Size
#
# ![Output Kernel Size](https://1.bp.blogspot.com/-db1Bv-YnKTo/XkrIvCYFtEI/AAAAAAAAArA/2b0zbD29CQML4IKxp_1Zng_r0ioaOCZkgCEwYBhgL/s1600/appendix_C_conv_formula.png)
#
# ## Transpose Convolution Output size
#
# ![Output kernel size](https://1.bp.blogspot.com/-TovEZzZ6sZo/XkrI0jqa_LI/AAAAAAAAArM/KRvM_I4oNoQEFu9Zzzk-lyCQUj8xFBeYwCEwYBhgL/s1600/appendix_C_transposeconv_formula.png)

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

physical_devices = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %load_ext watermark
# %watermark -a "Aneesh" -p tensorflow,tensorflow_datasets,tensorflow_addons,tensorflow_decision_forests,tensorflow_estimator,tensorflow_metadata,tensorflow_probability,wandb

print(f'GPU: {physical_devices}')
# Out:
# Author: Aneesh
#
# tensorflow                 : 2.10.0
# tensorflow_datasets        : 4.7.0
# tensorflow_addons          : 0.18.0
# tensorflow_decision_forests: 1.0.1
# tensorflow_estimator       : 2.10.0
# tensorflow_metadata        : 1.11.0
# tensorflow_probability     : 0.18.0
# wandb                      : 0.13.5
#
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
