# %% [markdown]
# # Very Deep Convolutions for Large Scale Image Recognition
#
#
# > Brief Intro to Convolutions: [here](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1)
#
# - Published as a conference paper at ICLR 2015.
#
# ## ConvNet Configurations
#
# ### Architecture
#
# - During training, the input to ConvNet is a fixed-size $224\times244$ RGB Image. The only pre-preprocessing we do is subtractig the mean RGB value, computed on tge training set, from each pixel.
#
# ![Screenshot%202022-12-08%20at%2011.20.06%20PM.png](attachment:Screenshot%202022-12-08%20at%2011.20.06%20PM.png)

# %% [markdown]
# ## Code

# %% [markdown]
# ### Imports

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

physical_devices = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %load_ext watermark
# %watermark -a "Aneesh" -p tensorflow,tensorflow_datasets,tensorflow_addons,tensorflow_decision_forests,tensorflow_estimator,tensorflow_metadata,tensorflow_probability,wandb

print(f'GPU: {physical_devices}')
# Out:
# Author: Aneesh
#
# tensorflow                 : 2.10.0
# tensorflow_datasets        : 4.7.0
# tensorflow_addons          : 0.18.0
# tensorflow_decision_forests: 1.0.1
# tensorflow_estimator       : 2.10.0
# tensorflow_metadata        : 1.11.0
# tensorflow_probability     : 0.18.0
# wandb                      : 0.13.5
#
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### VGG Implementation

# %% [markdown]
# ### Model Plot
